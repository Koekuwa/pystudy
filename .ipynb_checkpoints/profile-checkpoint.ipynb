# %%
n = 10000
# %timeit sum([1. / i**2 for i in range(1,n)])
# Out:
# 100 loops, best of 3: 4.16 ms per loop

# %%
#時間計測（要素）

# %%
# %timeit s = 0.
for i in range(1,n):
    s += 1. / i**2
# Out:
# 10000000 loops, best of 3: 25.8 ns per loop

# %%
import numpy as np
# %timeit np.sum(1. / np.arange(1. / n)**2)
# Out:
# /Users/okoshitakumi/.pyenv/versions/3.5.2/lib/python3.5/site-packages/ipykernel/__main__.py:257: RuntimeWarning: divide by zero encountered in true_divide
# The slowest run took 172.70 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 3: 10.8 µs per loop

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def step(*shape):
    return 2 * (np.random.random_sample(shape) < .5) - 1

# %prun -s cumulative -q -l 10 -T prun0
n = 10000
iterations = 500
x = np.cumsum(step(iterations, n), axis=0)
bins = np.arange(-30, 30, 1)
y = np.vstack([np.histogram(x[i,:],bins)[0] for i in range(iterations)])
print(open("prun0" , "r").read())
# Out:
#
# *** Profile printout saved to text file 'prun0'.
#          3 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)

# %%
#メモリー計測

# %%
# %load_ext memory_profiler
# %writefile simuration.py
def step(*shape):
    return 2 * (np.random.random_sample(shape) < .5) - 1

def simulate(iterations, n=10000):
    a = step(iterations, n)
    x = np.cumsum(s, axis=0)
    bins = np.arange(-30, 30, 1)
    y = np.vstack([np.histogram(x[i,:],bins)[0] for i in range(iterations)])
    return y

import simulation
# %mprun -T mprof0 -f simulation.simulate simulation.simulate(50)
print(open("mprof0" , "r").read())
# Out:
# -----------------------------------------------------------------
# ImportError                     Traceback (most recent call last)
# <ipython-input-20-267211189be2> in <module>()
# ----> 1 get_ipython().magic('load_ext memory_profiler')
#       2 get_ipython().magic('writefile simuration.py')
#       3 def step(*shape):
#       4     return 2 * (np.random.random_sample(shape) < .5) - 1
#       5
#
# /Users/okoshitakumi/.pyenv/versions/3.5.2/lib/python3.5/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/okoshitakumi/.pyenv/versions/3.5.2/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-62> in load_ext(self, module_str)
#
# /Users/okoshitakumi/.pyenv/versions/3.5.2/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/okoshitakumi/.pyenv/versions/3.5.2/lib/python3.5/site-packages/IPython/core/magics/extension.py in load_ext(self, module_str)
#      35         if not module_str:
#      36             raise UsageError('Missing module name.')
# ---> 37         res = self.shell.extension_manager.load_extension(module_str)
#      38
#      39         if res == 'already loaded':
#
# /Users/okoshitakumi/.pyenv/versions/3.5.2/lib/python3.5/site-packages/IPython/core/extensions.py in load_extension(self, module_str)
#      81             if module_str not in sys.modules:
#      82                 with prepended_to_syspath(self.ipython_extension_dir):
# ---> 83                     __import__(module_str)
#      84             mod = sys.modules[module_str]
#      85             if self._call_load_ipython_extension(mod):
#
# ImportError: No module named 'memory_profiler'

# %%
# %memit np.random.randn(1000, 1000)
# Out:
# ERROR:root:Line magic function `%memit` not found.

# %%
#移動平均

# %%
import numpy as np
from numpy.lib.stride_tricks import as_strided
n = 5; k = 2
a = np.linspace(1,n,n); aid = id(a)
as_strided(a, (k, n), (8, 8))
# Out:
# array([[  1.00000000e+000,   2.00000000e+000,   3.00000000e+000,
#           4.00000000e+000,   5.00000000e+000],
#        [  2.00000000e+000,   3.00000000e+000,   4.00000000e+000,
#           5.00000000e+000,   2.15705263e-314]])

# %%
as_strided(a, (k, n-k+1), (8, 8))
# Out:
# array([[ 1.,  2.,  3.,  4.],
#        [ 2.,  3.,  4.,  5.]])

# %%
#ネットワーク

# %%
import json
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g = nx.karate_club_graph()
nx.draw(g)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpld3 import enable_notebook
enable_notebook()

# %%
x = np.random.normal(0, 1, (100,3))
color = np.random.random(100)
size = 500 * np.random.random(100)
plt.scatter(x[:,0], x[:,1], c=color, s=size, alpha=0.5, linewidth=2)
plt.grid(color="lightgray", alpha=0.7)

# %%
fig, ax = plt.subplots(3, 3, figsize=(6, 6), sharex=True, sharey=True)
fig.subplots_adjust(hspace=0.3)
x[::2,2] += 3
for i in range(3):
    for j in range(3):
        ax[i,j].scatter(x[:,i], x[:,j], c=color, s=.1*size, alpha=0.5, linewidth=2)
        ax[i,j].grid(color="lightgray", alpha=0.7)
