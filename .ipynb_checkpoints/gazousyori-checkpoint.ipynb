# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage.exposure as skie
# %matplotlib inline

# %%
img = plt.imread("data/pic1.jpg")[..., 0]

# %%
def show(img):
    plt.subplot(121)
    plt.imshow(img, cmap=plt.cm.gray)
    plt.axis("off")
    plt.subplot(122)
    plt.hist(img.ravel(), lw=0, bins=256)
    plt.xlim(0, img.max())
    plt.yticks([])
    plt.show

# %%
show(img)

# %%
show(skie.rescale_intensity(img, in_range=(100, 240), out_range=(0, 255)))

# %%
show(skie.equalize_adapthist(img))

# %%
#画像フィルタ処理

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
import skimage.filters as skif
import skimage.data as skid
# %matplotlib inline

# %%
def show(img):
    plt.imshow(img, cmap=plt.cm.gray)
    plt.axis("off")
    plt.show()

# %%
img = plt.imread("data/satomi.jpg")[...,0]
show(img)

# %%
show(skif.gaussian(img, 5.))

# %%
sobimg = skif.sobel(img)
show(sobimg)

# %%
from ipywidgets import widgets
@widgets.interact(x=(0.001, .08, .005))
def edge(x):
    show(sobimg<x)

# %%
img = plt.imread("data/satomi.jpg")[...,0]
img = img[200:-150, 200:-250]
show(img)
img = np.clip(img + 15*np.random.rand(*img.shape), 0, 255)
show(img)

# %%
show(skimage.restoration.denoise_tv_bregman(img, 5.))

# %%
#画像分割

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.data import coins
from skimage.filters import threshold_otsu
from skimage.segmentation import clear_border
from skimage.morphology import closing, square
from skimage.measure import regionprops, label
from skimage.color import lab2rgb
# %matplotlib inline

# %%
def show(img, cmap=None):
    cmap = cmap or plt.cm.gray
    plt.imshow(img, cmap=cmap)
    plt.axis("off")
    plt.show()

# %%
img = coins()
show(img)

# %%
threshold_otsu(img)
# Out:
# 107

# %%
show(img>107)

# %%
from ipywidgets import widgets
@widgets.interact(t=(10, 240))
def threshold(t):
    show(img>t)

# %%
img_bin = clear_border(closing(img>120, square(5)))
show(img_bin)

# %%
labels = label(img_bin)
show(labels, cmap=plt.cm.rainbow)

# %%
regions = regionprops(labels, ["Area", "BoundingBox"])
boxes = np.array([label["BoundingBox"] for label in regions if label["Area"] > 100])
print("There are {0:d} coins.".format(len(boxes)))
# Out:
# ---------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-111-27c33c76c52d> in <module>()
# ----> 1 regions = regionprops(labels, ["Area", "BoundingBox"])
#       2 boxes = np.array([label["BoundingBox"] for label in regions if label["Area"] > 100])
#       3 print("There are {0:d} coins.".format(len(boxes)))
#
# /Users/okoshitakumi/.pyenv/versions/3.5.2/lib/python3.5/site-packages/skimage/measure/_regionprops.py in regionprops(label_image, intensity_image, cache)
#     533
#     534         props = _RegionProperties(sl, label, label_image, intensity_image,
# --> 535                                   cache)
#     536         regions.append(props)
#     537
#
# /Users/okoshitakumi/.pyenv/versions/3.5.2/lib/python3.5/site-packages/skimage/measure/_regionprops.py in __init__(self, slice, label, label_image, intensity_image, cache_active)
#      95
#      96         if intensity_image is not None:
# ---> 97             if not intensity_image.shape == label_image.shape:
#      98                 raise ValueError('Label and intensity image must have the same shape.')
#      99
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
#特徴点抽出

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
import skimage.feature as sf
# %matplotlib inline

# %%
def show(img, cmap=None):
    cmap = cmap or plt.cm.gray
    plt.imshow(img, cmap=cmap)
    plt.axis("off")

# %%
img = plt.imread("data/pic2.jpg")
show(img)

# %%
corners = sf.corner_harris(img[:,:,0])
show(corners)

# %%
peaks = sf.corner_peaks(corners)
show(img)
plt.plot(peaks[:,1], peaks[:,0], "or", ms=4)

# %%
ymin, xmin = peaks.min(axis=0)
ymax, xmax = peaks.max(axis=0)
w, h = xmax-xmin, ymax-ymin
k = .25
xmin -= k*w
xmax += k*w
ymin -= k*h
ymax += k*h
show(img[ymin:ymax,xmin:xmax])
# Out:
# /Users/okoshitakumi/.pyenv/versions/3.5.2/lib/python3.5/site-packages/ipykernel/__main__.py:9: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
#OpenCV顔検出

# %%
import cv2
# Out:
# ---------------------------------------
# ImportErrorTraceback (most recent call last)
# <ipython-input-2-72fbbcfe2587> in <module>()
# ----> 1 import cv2
#
# ImportError: No module named 'cv2'
