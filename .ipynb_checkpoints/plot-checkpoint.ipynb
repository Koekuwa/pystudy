# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
np.random.seed(12)
for i in range(8):
    x = np.arange(1000)
    y = np.random.randn(1000).cumsum()
    plt.plot(x,y,label=str(i))
plt.legend
# Out:
# <function matplotlib.pyplot.legend>

# %%
import prettyplotlib as ppl
np.random.seed(12)
for i in range(8):
    x = np.arange(1000)
    y = np.random.randn(1000).cumsum()
    ppl.plot(x,y,label=str(i))
ppl.legend
# Out:
# /Users/okoshitakumi/.pyenv/versions/3.5.2/lib/python3.5/site-packages/matplotlib/__init__.py:878: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# <function prettyplotlib._legend.legend>

# %%
np.random.seed(12)
plt.pcolormesh(np.random.rand(16,16))
plt.colorbar()

# %%
np.random.seed(12)
ppl.pcolormesh(np.random.rand(16,16))

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
x1 = np.random.randn(80)
x2 = np.random.randn(80)
x3 = x1 * x2
y1 = .5 + 2 * x1 - x2 + 2.5 * x3 + 3 * np.random.randn(80)
y2 = .5 + 2 * x1 - x2 + 2.5 * np.random.randn(80)
y3 = y2 + np.random.randn(80)
sns.violinplot(x1)
sns.violinplot(x2)

# %%
sns.regplot(x2,y2)

# %%
import pandas as pd
df = pd.DataFrame(dict(x1=x1, x2=x2, x3=x3, y1=y1, y2=y2, y3=y3))
sns.corrplot(df)
# Out:
# ---------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-27-345abde5ce5e> in <module>()
#       1 import pandas as pd
#       2 df = pd.DataFrame(dict(x1=x1, x2=x2, x3=x3, y1=y1, y2=y2, y3=y3))
# ----> 3 sns.corrplot(df)
#
# AttributeError: module 'seaborn' has no attribute 'corrplot'

# %%
import numpy as np
import bokeh.plotting as bkh
bkh.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="60722a2e-b502-4544-b218-70d4ff4970ba">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(0., 1., 100)
y = np.cumsum(np.random.randn(100))
bkh.line(x, y, line_width=5)
bkh.show
# Out:
# ---------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-32-ffb845fc3dea> in <module>()
#       1 x = np.linspace(0., 1., 100)
#       2 y = np.cumsum(np.random.randn(100))
# ----> 3 bkh.line(x, y, line_width=5)
#       4 bkh.show
#
# AttributeError: module 'bokeh.plotting' has no attribute 'line'

# %%
from bokeh.sampledata.iris import flowers
colormap = {"setosa": "red", "versicolor": "green", "virginica": "blue"}
flowers["color"] = flowers["species"].map(lambda x: colormap[x])
bkh.scatter(flowers["petal_length"], flowers["petal_width"], color=flowers["color"], fill_alpha=0.25, size=10,)
bkd.show
# Out:
# ---------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-34-d128153f0625> in <module>()
#       2 colormap = {"setosa": "red", "versicolor": "green", "virginica": "blue"}
#       3 flowers["color"] = flowers["species"].map(lambda x: colormap[x])
# ----> 4 bkh.scatter(flowers["petal_length"], flowers["petal_width"], color=flowers["color"], fill_alpha=0.25, size=10,)
#       5 bkd.show
#
# AttributeError: module 'bokeh.plotting' has no attribute 'scatter'
